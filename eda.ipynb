# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('./datasets/train.csv')
test = pd.read_csv('./datasets/test.csv')

# %% [markdown]
# <font size="3"><b>Exploratory Data Analysis</b></font><br>
# For this section, all the variables were examined. Missing data were adjusted where appropropriate.

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     SalePrice - the property's sale price in dollars
#     </b></font>
# </font>

# %%
print('Missing Data|' + 'Train:' + str(train['SalePrice'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|

# %%
train['SalePrice']
# Out:
# 0       130500
# 1       220000
# 2       109000
# 3       174000
# 4       138500
#          ...
# 2046    298751
# 2047     82500
# 2048    177000
# 2049    144000
# 2050    189000
# Name: SalePrice, Length: 2051, dtype: int64

# %%
train['SalePrice'].describe()
# Out:
# count      2051.000000
# mean     181469.701609
# std       79258.659352
# min       12789.000000
# 25%      129825.000000
# 50%      162500.000000
# 75%      214000.000000
# max      611657.000000
# Name: SalePrice, dtype: float64

# %%
train['SalePrice'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["SalePrice"])
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     MS SubClass : The building class
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['MS SubClass'].isnull().sum()) +
                        '|Test:'+ str(test['MS SubClass'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['MS SubClass'].value_counts().sort_index(ascending=True)
# Out:
# 20     770
# 30     101
# 40       4
# 45      11
# 50     198
# 60     394
# 70      90
# 75      16
# 80      86
# 85      28
# 90      75
# 120    132
# 150      1
# 160     88
# 180     11
# 190     46
# Name: MS SubClass, dtype: int64

# %%
test['MS SubClass'].value_counts().sort_index(ascending=True)
# Out:
# 20     309
# 30      38
# 40       2
# 45       7
# 50      89
# 60     180
# 70      38
# 75       7
# 80      32
# 85      20
# 90      34
# 120     60
# 160     41
# 180      6
# 190     15
# Name: MS SubClass, dtype: int64

# %%
train.sort_values('MS SubClass', inplace=True)
train['MS SubClass'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('MS SubClass', inplace=True)
test['MS SubClass'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='MS SubClass', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='MS SubClass', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     MS Zoning : Identifies the general zoning classification of the sale.
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['MS Zoning'].isnull().sum()) +
                        '|Test:'+ str(test['MS Zoning'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['MS Zoning'].value_counts().sort_index(ascending=True)
# Out:
# A (agr)       2
# C (all)      19
# FV          101
# I (all)       1
# RH           14
# RL         1598
# RM          316
# Name: MS Zoning, dtype: int64

# %%
test['MS Zoning'].value_counts().sort_index(ascending=True)
# Out:
# C (all)      6
# FV          38
# I (all)      1
# RH          13
# RL         674
# RM         146
# Name: MS Zoning, dtype: int64

# %%
train.sort_values('MS Zoning', inplace=True)
train['MS Zoning'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('MS Zoning', inplace=True)
test['MS Zoning'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='MS Zoning', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='MS Zoning', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Lot Frontage : Linear feet of street connected to property
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Lot Frontage'].isnull().sum()) +
                        '|Test:'+ str(test['Lot Frontage'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:330|Test:160|

# %%
#Recode missing value as 0
train['Lot Frontage'] = train['Lot Frontage'].replace(np.nan, 0)
test['Lot Frontage'] = test['Lot Frontage'].replace(np.nan, 0)

# %%
train['Lot Frontage'].describe()
# Out:
# count    2051.000000
# mean       57.944417
# std        33.137332
# min         0.000000
# 25%        43.500000
# 50%        63.000000
# 75%        78.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
test['Lot Frontage'].describe()
# Out:
# count    878.000000
# mean      56.872437
# std       34.269502
# min        0.000000
# 25%       40.000000
# 50%       60.000000
# 75%       78.000000
# max      182.000000
# Name: Lot Frontage, dtype: float64

# %%
train['Lot Frontage'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test['Lot Frontage'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Lot Frontage"])
# Out:
# <AxesSubplot:xlabel='Lot Frontage'>

# %%
sns.boxplot(x=test["Lot Frontage"])
# Out:
# <AxesSubplot:xlabel='Lot Frontage'>

# %%
plt.scatter(train['Lot Frontage'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Lot Area : Lot size in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Lot Area'].isnull().sum()) +
                        '|Test:'+ str(test['Lot Area'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Lot Area'].describe()
# Out:
# count      2051.000000
# mean      10065.208191
# std        6742.488909
# min        1300.000000
# 25%        7500.000000
# 50%        9430.000000
# 75%       11513.500000
# max      159000.000000
# Name: Lot Area, dtype: float64

# %%
test['Lot Area'].describe()
# Out:
# count       878.000000
# mean      10307.033030
# std       10002.674602
# min        1477.000000
# 25%        7297.250000
# 50%        9446.000000
# 75%       11589.000000
# max      215245.000000
# Name: Lot Area, dtype: float64

# %%
train['Lot Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test['Lot Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Lot Area"])
# Out:
# <AxesSubplot:xlabel='Lot Area'>

# %%
sns.boxplot(x=test["Lot Area"])
# Out:
# <AxesSubplot:xlabel='Lot Area'>

# %%
plt.scatter(train['Lot Area'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Street: Type of road access to property
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Street'].isnull().sum()) +
                        '|Test:'+ str(test['Street'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Street'].value_counts().sort_index(ascending=True)
# Out:
# Grvl       7
# Pave    2044
# Name: Street, dtype: int64

# %%
test['Street'].value_counts().sort_index(ascending=True)
# Out:
# Grvl      5
# Pave    873
# Name: Street, dtype: int64

# %%
train.sort_values('Street', inplace=True)
train['Street'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Street', inplace=True)
test['Street'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Street', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Street', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Alley: Type of alley access to property
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Alley'].isnull().sum()) +
                        '|Test:'+ str(test['Alley'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1911|Test:820|

# %%
#Recode missing value as 0
train['Alley'] = train['Alley'].replace(np.nan, 'No Alley')
test['Alley'] = test['Alley'].replace(np.nan, 'No Alley')

# %%
train['Alley'].value_counts().sort_index(ascending=True)
# Out:
# Grvl          85
# No Alley    1911
# Pave          55
# Name: Alley, dtype: int64

# %%
test['Alley'].value_counts().sort_index(ascending=True)
# Out:
# Grvl         35
# No Alley    820
# Pave         23
# Name: Alley, dtype: int64

# %%
train.sort_values('Alley', inplace=True)
train['Alley'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Alley', inplace=True)
test['Alley'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Alley', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Alley', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Lot Shape: General shape of property
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Lot Shape'].isnull().sum()) +
                        '|Test:'+ str(test['Lot Shape'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Lot Shape'].value_counts().sort_index(ascending=True)
# Out:
# IR1     692
# IR2      55
# IR3       9
# Reg    1295
# Name: Lot Shape, dtype: int64

# %%
test['Lot Shape'].value_counts().sort_index(ascending=True)
# Out:
# IR1    286
# IR2     21
# IR3      7
# Reg    564
# Name: Lot Shape, dtype: int64

# %%
train.sort_values('Lot Shape', inplace=True)
train['Lot Shape'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Lot Shape', inplace=True)
test['Lot Shape'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Lot Shape', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Lot Shape', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Land Contour: Flatness of the property
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Land Contour'].isnull().sum()) +
                        '|Test:'+ str(test['Land Contour'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Land Contour'].value_counts().sort_index(ascending=True)
# Out:
# Bnk      80
# HLS      85
# Low      43
# Lvl    1843
# Name: Land Contour, dtype: int64

# %%
test['Land Contour'].value_counts().sort_index(ascending=True)
# Out:
# Bnk     36
# HLS     35
# Low     17
# Lvl    790
# Name: Land Contour, dtype: int64

# %%
train.sort_values('Land Contour', inplace=True)
train['Land Contour'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Land Contour', inplace=True)
test['Land Contour'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Land Contour', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Land Contour', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Utilities: Type of utilities available
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Utilities'].isnull().sum()) +
                        '|Test:'+ str(test['Utilities'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Utilities'].value_counts().sort_index(ascending=True)
# Out:
# AllPub    2049
# NoSeWa       1
# NoSewr       1
# Name: Utilities, dtype: int64

# %%
test['Utilities'].value_counts().sort_index(ascending=True)
# Out:
# AllPub    877
# NoSewr      1
# Name: Utilities, dtype: int64

# %%
train.sort_values('Utilities', inplace=True)
train['Utilities'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Utilities', inplace=True)
test['Utilities'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Utilities', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Utilities', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Lot Config: Lot configuration
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Lot Config'].isnull().sum()) +
                        '|Test:'+ str(test['Lot Config'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Lot Config'].value_counts().sort_index(ascending=True)
# Out:
# Corner      348
# CulDSac     131
# FR2          60
# FR3           9
# Inside     1503
# Name: Lot Config, dtype: int64

# %%
test['Lot Config'].value_counts().sort_index(ascending=True)
# Out:
# Corner     163
# CulDSac     49
# FR2         25
# FR3          5
# Inside     636
# Name: Lot Config, dtype: int64

# %%
train.sort_values('Lot Config', inplace=True)
train['Lot Config'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Lot Config', inplace=True)
test['Lot Config'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Lot Config', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Lot Config', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Land Slope: Lot configuration
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Land Slope'].isnull().sum()) +
                        '|Test:'+ str(test['Land Slope'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Land Slope'].value_counts().sort_index(ascending=True)
# Out:
# Gtl    1953
# Mod      88
# Sev      10
# Name: Land Slope, dtype: int64

# %%
test['Land Slope'].value_counts().sort_index(ascending=True)
# Out:
# Gtl    835
# Mod     37
# Sev      6
# Name: Land Slope, dtype: int64

# %%
train.sort_values('Land Slope', inplace=True)
train['Land Slope'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Land Slope', inplace=True)
test['Land Slope'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Land Slope', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Land Slope', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Neighborhood: Physical locations within Ames city limits
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Neighborhood'].isnull().sum()) +
                        '|Test:'+ str(test['Neighborhood'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Neighborhood'].value_counts().sort_index(ascending=True)
# Out:
# Blmngtn     22
# Blueste      6
# BrDale      19
# BrkSide     76
# ClearCr     27
# CollgCr    180
# Crawfor     71
# Edwards    143
# Gilbert    116
# Greens       3
# GrnHill      2
# IDOTRR      69
# Landmrk      1
# MeadowV     24
# Mitchel     82
# NAmes      310
# NPkVill     17
# NWAmes      87
# NoRidge     48
# NridgHt    122
# OldTown    163
# SWISU       32
# Sawyer     111
# SawyerW     87
# Somerst    130
# StoneBr     38
# Timber      48
# Veenker     17
# Name: Neighborhood, dtype: int64

# %%
test['Neighborhood'].value_counts().sort_index(ascending=True)
# Out:
# Blmngtn      6
# Blueste      4
# BrDale      11
# BrkSide     32
# ClearCr     17
# CollgCr     87
# Crawfor     32
# Edwards     50
# Gilbert     49
# Greens       5
# IDOTRR      24
# MeadowV     13
# Mitchel     32
# NAmes      133
# NPkVill      6
# NWAmes      44
# NoRidge     23
# NridgHt     44
# OldTown     76
# SWISU       16
# Sawyer      40
# SawyerW     38
# Somerst     52
# StoneBr     13
# Timber      24
# Veenker      7
# Name: Neighborhood, dtype: int64

# %%
train.sort_values('Neighborhood', inplace=True)
train['Neighborhood'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Neighborhood', inplace=True)
test['Neighborhood'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Neighborhood', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Condition 1: Proximity to main road or railroad
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Condition 1'].isnull().sum()) +
                        '|Test:'+ str(test['Condition 1'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Condition 1'].value_counts().sort_index(ascending=True)
# Out:
# Artery      70
# Feedr      109
# Norm      1767
# PosA        12
# PosN        27
# RRAe        21
# RRAn        36
# RRNe         3
# RRNn         6
# Name: Condition 1, dtype: int64

# %%
test['Condition 1'].value_counts().sort_index(ascending=True)
# Out:
# Artery     22
# Feedr      55
# Norm      755
# PosA        8
# PosN       11
# RRAe        7
# RRAn       14
# RRNe        3
# RRNn        3
# Name: Condition 1, dtype: int64

# %%
train.sort_values('Condition 1', inplace=True)
train['Condition 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Condition 1', inplace=True)
test['Condition 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Condition 1', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Condition 1', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Condition 2: Proximity to main road or railroad (if a second is present)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Condition 2'].isnull().sum()) +
                        '|Test:'+ str(test['Condition 2'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Condition 2'].value_counts().sort_index(ascending=True)
# Out:
# Artery       5
# Feedr       11
# Norm      2025
# PosA         3
# PosN         3
# RRAe         1
# RRAn         1
# RRNn         2
# Name: Condition 2, dtype: int64

# %%
test['Condition 2'].value_counts().sort_index(ascending=True)
# Out:
# Feedr      2
# Norm     875
# PosA       1
# Name: Condition 2, dtype: int64

# %%
train.sort_values('Condition 2', inplace=True)
train['Condition 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Condition 2', inplace=True)
test['Condition 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Condition 2', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Condition 2', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Bldg Type: Type of dwelling
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bldg Type'].isnull().sum()) +
                        '|Test:'+ str(test['Bldg Type'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Bldg Type'].value_counts().sort_index(ascending=True)
# Out:
# 1Fam      1700
# 2fmCon      46
# Duplex      75
# Twnhs       69
# TwnhsE     161
# Name: Bldg Type, dtype: int64

# %%
test['Bldg Type'].value_counts().sort_index(ascending=True)
# Out:
# 1Fam      724
# 2fmCon     16
# Duplex     34
# Twnhs      32
# TwnhsE     72
# Name: Bldg Type, dtype: int64

# %%
train.sort_values('Bldg Type', inplace=True)
train['Bldg Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bldg Type', inplace=True)
test['Bldg Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Bldg Type', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Bldg Type', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     House Style: Style of dwelling
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['House Style'].isnull().sum()) +
                        '|Test:'+ str(test['House Style'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['House Style'].value_counts().sort_index(ascending=True)
# Out:
# 1.5Fin     218
# 1.5Unf      12
# 1Story    1059
# 2.5Fin       6
# 2.5Unf      14
# 2Story     598
# SFoyer      50
# SLvl        94
# Name: House Style, dtype: int64

# %%
test['House Style'].value_counts().sort_index(ascending=True)
# Out:
# 1.5Fin     96
# 1.5Unf      7
# 1Story    422
# 2.5Fin      2
# 2.5Unf     10
# 2Story    274
# SFoyer     33
# SLvl       34
# Name: House Style, dtype: int64

# %%
train.sort_values('House Style', inplace=True)
train['House Style'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('House Style', inplace=True)
test['House Style'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='House Style', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='House Style', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Scale]</font>
#     Overall Qual: Overall material and finish quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Overall Qual'].isnull().sum()) +
                        '|Test:'+ str(test['Overall Qual'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Overall Qual'].value_counts().sort_index(ascending=True)
# Out:
# 1       4
# 2       9
# 3      29
# 4     159
# 5     563
# 6     506
# 7     431
# 8     250
# 9      77
# 10     23
# Name: Overall Qual, dtype: int64

# %%
test['Overall Qual'].value_counts().sort_index(ascending=True)
# Out:
# 2       4
# 3      11
# 4      67
# 5     262
# 6     226
# 7     171
# 8     100
# 9      30
# 10      7
# Name: Overall Qual, dtype: int64

# %%
train['Overall Qual'].describe()
# Out:
# count    2051.000000
# mean        6.112140
# std         1.426271
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: Overall Qual, dtype: float64

# %%
test['Overall Qual'].describe()
# Out:
# count    878.000000
# mean       6.050114
# std        1.369065
# min        2.000000
# 25%        5.000000
# 50%        6.000000
# 75%        7.000000
# max       10.000000
# Name: Overall Qual, dtype: float64

# %%
train.sort_values('Overall Qual', inplace=True)
train['Overall Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Overall Qual', inplace=True)
test['Overall Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Overall Qual"])
# Out:
# <AxesSubplot:xlabel='Overall Qual'>

# %%
sns.boxplot(x=test["Overall Qual"])
# Out:
# <AxesSubplot:xlabel='Overall Qual'>

# %%
plt.scatter(train['Overall Qual'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Scale]</font>
#     Overall Cond: Overall condition rating
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Overall Cond'].isnull().sum()) +
                        '|Test:'+ str(test['Overall Cond'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Overall Cond'].value_counts().sort_index(ascending=True)
# Out:
# 1       4
# 2       6
# 3      35
# 4      70
# 5    1168
# 6     368
# 7     270
# 8     101
# 9      29
# Name: Overall Cond, dtype: int64

# %%
test['Overall Cond'].value_counts().sort_index(ascending=True)
# Out:
# 1      3
# 2      4
# 3     15
# 4     31
# 5    485
# 6    165
# 7    120
# 8     43
# 9     12
# Name: Overall Cond, dtype: int64

# %%
train['Overall Cond'].describe()
# Out:
# count    2051.000000
# mean        5.562165
# std         1.104497
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: Overall Cond, dtype: float64

# %%
test['Overall Cond'].describe()
# Out:
# count    878.000000
# mean       5.566059
# std        1.128903
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        6.000000
# max        9.000000
# Name: Overall Cond, dtype: float64

# %%
train.sort_values('Overall Cond', inplace=True)
train['Overall Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Overall Cond', inplace=True)
test['Overall Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Overall Cond"])
# Out:
# <AxesSubplot:xlabel='Overall Cond'>

# %%
sns.boxplot(x=test["Overall Cond"])
# Out:
# <AxesSubplot:xlabel='Overall Cond'>

# %%
plt.scatter(train['Overall Cond'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Year Built: Original construction date
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Year Built'].isnull().sum()) +
                        '|Test:'+ str(test['Year Built'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Year Built'].describe()
# Out:
# count    2051.000000
# mean     1971.708922
# std        30.177889
# min      1872.000000
# 25%      1953.500000
# 50%      1974.000000
# 75%      2001.000000
# max      2010.000000
# Name: Year Built, dtype: float64

# %%
test['Year Built'].describe()
# Out:
# count     878.000000
# mean     1970.492027
# std        30.395895
# min      1880.000000
# 25%      1954.000000
# 50%      1972.000000
# 75%      1999.750000
# max      2010.000000
# Name: Year Built, dtype: float64

# %%
train.sort_values('Year Built', inplace=True)
train['Year Built'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Year Built', inplace=True)
test['Year Built'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Year Built"])
# Out:
# <AxesSubplot:xlabel='Year Built'>

# %%
sns.boxplot(x=test["Year Built"])
# Out:
# <AxesSubplot:xlabel='Year Built'>

# %%
plt.scatter(train['Year Built'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Year RemodAdd: Remodel date (same as construction date if no remodeling or additions)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Year Remod/Add'].isnull().sum()) +
                        '|Test:'+ str(test['Year Remod/Add'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Year Remod/Add'].describe()
# Out:
# count    2051.000000
# mean     1984.190151
# std        21.036250
# min      1950.000000
# 25%      1964.500000
# 50%      1993.000000
# 75%      2004.000000
# max      2010.000000
# Name: Year Remod/Add, dtype: float64

# %%
test['Year Remod/Add'].describe()
# Out:
# count     878.000000
# mean     1984.417995
# std        20.450725
# min      1950.000000
# 25%      1967.000000
# 50%      1992.000000
# 75%      2003.000000
# max      2010.000000
# Name: Year Remod/Add, dtype: float64

# %%
train.sort_values('Year Remod/Add', inplace=True)
train['Year Remod/Add'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Year Remod/Add', inplace=True)
test['Year Remod/Add'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Year Remod/Add"])
# Out:
# <AxesSubplot:xlabel='Year Remod/Add'>

# %%
sns.boxplot(x=test["Year Remod/Add"])
# Out:
# <AxesSubplot:xlabel='Year Remod/Add'>

# %%
plt.scatter(train['Year Remod/Add'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Roof Style: Type of roof
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Roof Style'].isnull().sum()) +
                        '|Test:'+ str(test['Roof Style'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Roof Style'].value_counts().sort_index(ascending=True)
# Out:
# Flat         13
# Gable      1619
# Gambrel      12
# Hip         397
# Mansard       7
# Shed          3
# Name: Roof Style, dtype: int64

# %%
test['Roof Style'].value_counts().sort_index(ascending=True)
# Out:
# Flat         7
# Gable      702
# Gambrel     10
# Hip        153
# Mansard      4
# Shed         2
# Name: Roof Style, dtype: int64

# %%
train.sort_values('Roof Style', inplace=True)
train['Roof Style'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Roof Style', inplace=True)
test['Roof Style'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Roof Style', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Roof Style', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Roof Matl: Roof material
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Roof Matl'].isnull().sum()) +
                        '|Test:'+ str(test['Roof Matl'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Roof Matl'].value_counts().sort_index(ascending=True)
# Out:
# ClyTile       1
# CompShg    2025
# Membran       1
# Tar&Grv      15
# WdShake       4
# WdShngl       5
# Name: Roof Matl, dtype: int64

# %%
test['Roof Matl'].value_counts().sort_index(ascending=True)
# Out:
# CompShg    861
# Metal        1
# Roll         1
# Tar&Grv      8
# WdShake      5
# WdShngl      2
# Name: Roof Matl, dtype: int64

# %%
train.sort_values('Roof Matl', inplace=True)
train['Roof Matl'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Roof Matl', inplace=True)
test['Roof Matl'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Roof Matl', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Roof Matl', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Exterior 1st: Exterior covering on house
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Exterior 1st'].isnull().sum()) +
                        '|Test:'+ str(test['Exterior 1st'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Exterior 1st'].value_counts().sort_index(ascending=True)
# Out:
# AsbShng     33
# AsphShn      1
# BrkComm      3
# BrkFace     64
# CBlock       2
# CemntBd     90
# HdBoard    300
# ImStucc      1
# MetalSd    331
# Plywood    152
# Stone        2
# Stucco      27
# VinylSd    724
# Wd Sdng    276
# WdShing     45
# Name: Exterior 1st, dtype: int64

# %%
test['Exterior 1st'].value_counts().sort_index(ascending=True)
# Out:
# AsbShng     11
# AsphShn      1
# BrkComm      3
# BrkFace     24
# CemntBd     35
# HdBoard    142
# MetalSd    119
# Plywood     69
# PreCast      1
# Stucco      16
# VinylSd    302
# Wd Sdng    144
# WdShing     11
# Name: Exterior 1st, dtype: int64

# %%
train.sort_values('Exterior 1st', inplace=True)
train['Exterior 1st'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Exterior 1st', inplace=True)
test['Exterior 1st'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Exterior 1st', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Exterior 1st', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Exterior 2nd: Exterior covering on house (if more than one material)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Exterior 2nd'].isnull().sum()) +
                        '|Test:'+ str(test['Exterior 2nd'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Exterior 2nd'].value_counts().sort_index(ascending=True)
# Out:
# AsbShng     28
# AsphShn      3
# Brk Cmn     17
# BrkFace     34
# CBlock       2
# CmentBd     90
# HdBoard    275
# ImStucc     11
# MetalSd    324
# Plywood    185
# Stone        6
# Stucco      30
# VinylSd    721
# Wd Sdng    262
# Wd Shng     63
# Name: Exterior 2nd, dtype: int64

# %%
test['Exterior 2nd'].value_counts().sort_index(ascending=True)
# Out:
# AsbShng     10
# AsphShn      1
# Brk Cmn      5
# BrkFace     13
# CBlock       1
# CmentBd     35
# HdBoard    131
# ImStucc      4
# MetalSd    123
# Other        1
# Plywood     89
# PreCast      1
# Stucco      17
# VinylSd    294
# Wd Sdng    135
# Wd Shng     18
# Name: Exterior 2nd, dtype: int64

# %%
train.sort_values('Exterior 2nd', inplace=True)
train['Exterior 2nd'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Exterior 2nd', inplace=True)
test['Exterior 2nd'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Exterior 2nd', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Exterior 2nd', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Mas Vnr Type: Masonry veneer type
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Mas Vnr Type'].isnull().sum()) +
                        '|Test:'+ str(test['Mas Vnr Type'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:22|Test:1|

# %%
#Recode missing value as 0
train['Mas Vnr Type'] = train['Mas Vnr Type'].replace(np.nan, 'None')
test['Mas Vnr Type'] = test['Mas Vnr Type'].replace(np.nan, 'None')

# %%
train['Mas Vnr Type'].value_counts().sort_index(ascending=True)
# Out:
# BrkCmn       13
# BrkFace     630
# None       1240
# Stone       168
# Name: Mas Vnr Type, dtype: int64

# %%
test['Mas Vnr Type'].value_counts().sort_index(ascending=True)
# Out:
# BrkCmn      12
# BrkFace    250
# CBlock       1
# None       535
# Stone       80
# Name: Mas Vnr Type, dtype: int64

# %%
train.sort_values('Mas Vnr Type', inplace=True)
train['Mas Vnr Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Mas Vnr Type', inplace=True)
test['Mas Vnr Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Mas Vnr Type', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Mas Vnr Type', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Mas Vnr Area: Masonry veneer area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Mas Vnr Area'].isnull().sum()) +
                        '|Test:'+ str(test['Mas Vnr Area'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:22|Test:1|

# %%
#Recode missing value as 0
train['Mas Vnr Area'] = train['Mas Vnr Area'].replace(np.nan, 0)
test['Mas Vnr Area'] = test['Mas Vnr Area'].replace(np.nan, 0)

# %%
train['Mas Vnr Area'].describe()
# Out:
# count    2051.000000
# mean       98.626524
# std       174.324690
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       159.000000
# max      1600.000000
# Name: Mas Vnr Area, dtype: float64

# %%
test['Mas Vnr Area'].describe()
# Out:
# count     878.000000
# mean      106.115034
# std       187.086530
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       171.750000
# max      1378.000000
# Name: Mas Vnr Area, dtype: float64

# %%
train.sort_values('Mas Vnr Type', inplace=True)
train['Mas Vnr Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Mas Vnr Type', inplace=True)
test['Mas Vnr Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Mas Vnr Area"])
# Out:
# <AxesSubplot:xlabel='Mas Vnr Area'>

# %%
sns.boxplot(x=test["Mas Vnr Area"])
# Out:
# <AxesSubplot:xlabel='Mas Vnr Area'>

# %%
plt.scatter(train['Mas Vnr Area'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Exter Qual: Exterior material quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Exter Qual'].isnull().sum()) +
                        '|Test:'+ str(test['Exter Qual'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1

train['Exter Qual'] = train['Exter Qual'].replace('Ex', 5)
train['Exter Qual'] = train['Exter Qual'].replace('Gd', 4)
train['Exter Qual'] = train['Exter Qual'].replace('TA', 3)
train['Exter Qual'] = train['Exter Qual'].replace('Fa', 2)
train['Exter Qual'] = train['Exter Qual'].replace('Po', 1)
test['Exter Qual'] = test['Exter Qual'].replace('Ex', 5)
test['Exter Qual'] = test['Exter Qual'].replace('Gd', 4)
test['Exter Qual'] = test['Exter Qual'].replace('TA', 3)
test['Exter Qual'] = test['Exter Qual'].replace('Fa', 2)
test['Exter Qual'] = test['Exter Qual'].replace('Po', 1)

# %%
train['Exter Qual'].value_counts().sort_index(ascending=True)
# Out:
# 2      26
# 3    1247
# 4     697
# 5      81
# Name: Exter Qual, dtype: int64

# %%
test['Exter Qual'].value_counts().sort_index(ascending=True)
# Out:
# 2      9
# 3    552
# 4    292
# 5     25
# Name: Exter Qual, dtype: int64

# %%
train['Exter Qual'].describe()
# Out:
# count    2051.000000
# mean        3.406143
# std         0.587962
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Exter Qual, dtype: float64

# %%
test['Exter Qual'].describe()
# Out:
# count    878.000000
# mean       3.379271
# std        0.559670
# min        2.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Exter Qual, dtype: float64

# %%
train.sort_values('Exter Qual', inplace=True)
train['Exter Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Exter Qual', inplace=True)
test['Exter Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Exter Qual"])
# Out:
# <AxesSubplot:xlabel='Exter Qual'>

# %%
sns.boxplot(x=test["Exter Qual"])
# Out:
# <AxesSubplot:xlabel='Exter Qual'>

# %%
plt.scatter(train['Exter Qual'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Exter Cond: Present condition of the material on the exterior
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Exter Cond'].isnull().sum()) +
                        '|Test:'+ str(test['Exter Cond'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1

train['Exter Cond'] = train['Exter Cond'].replace('Ex', 5)
train['Exter Cond'] = train['Exter Cond'].replace('Gd', 4)
train['Exter Cond'] = train['Exter Cond'].replace('TA', 3)
train['Exter Cond'] = train['Exter Cond'].replace('Fa', 2)
train['Exter Cond'] = train['Exter Cond'].replace('Po', 1)

test['Exter Cond'] = test['Exter Cond'].replace('Ex', 5)
test['Exter Cond'] = test['Exter Cond'].replace('Gd', 4)
test['Exter Cond'] = test['Exter Cond'].replace('TA', 3)
test['Exter Cond'] = test['Exter Cond'].replace('Fa', 2)
test['Exter Cond'] = test['Exter Cond'].replace('Po', 1)

# %%
train['Exter Cond'].value_counts().sort_index(ascending=True)
# Out:
# 1       2
# 2      49
# 3    1778
# 4     215
# 5       7
# Name: Exter Cond, dtype: int64

# %%
test['Exter Cond'].value_counts().sort_index(ascending=True)
# Out:
# 1      1
# 2     18
# 3    770
# 4     84
# 5      5
# Name: Exter Cond, dtype: int64

# %%
train['Exter Cond'].describe()
# Out:
# count    2051.000000
# mean        3.085812
# std         0.372792
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Exter Cond, dtype: float64

# %%
test['Exter Cond'].describe()
# Out:
# count    878.000000
# mean       3.084282
# std        0.369540
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Exter Cond, dtype: float64

# %%
train.sort_values('Exter Cond', inplace=True)
train['Exter Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Exter Cond', inplace=True)
test['Exter Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Exter Cond"])
# Out:
# <AxesSubplot:xlabel='Exter Cond'>

# %%
sns.boxplot(x=test["Exter Cond"])
# Out:
# <AxesSubplot:xlabel='Exter Cond'>

# %%
plt.scatter(train['Exter Cond'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Foundation: Type of foundation
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Foundation'].isnull().sum()) +
                        '|Test:'+ str(test['Foundation'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Foundation'].value_counts().sort_index(ascending=True)
# Out:
# BrkTil    221
# CBlock    863
# PConc     926
# Slab       34
# Stone       5
# Wood        2
# Name: Foundation, dtype: int64

# %%
test['Foundation'].value_counts().sort_index(ascending=True)
# Out:
# BrkTil     90
# CBlock    381
# PConc     383
# Slab       15
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
train.sort_values('Foundation', inplace=True)
train['Foundation'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Foundation', inplace=True)
test['Foundation'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Foundation', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Foundation', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Bsmt Qual: Height of the basement
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Qual'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Qual'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:55|Test:25|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0

train['Bsmt Qual'] = train['Bsmt Qual'].replace('Ex', 5)
train['Bsmt Qual'] = train['Bsmt Qual'].replace('Gd', 4)
train['Bsmt Qual'] = train['Bsmt Qual'].replace('TA', 3)
train['Bsmt Qual'] = train['Bsmt Qual'].replace('Fa', 2)
train['Bsmt Qual'] = train['Bsmt Qual'].replace('Po', 1)
train['Bsmt Qual'] = train['Bsmt Qual'].replace(np.nan, 0)
test['Bsmt Qual'] = test['Bsmt Qual'].replace('Ex', 5)
test['Bsmt Qual'] = test['Bsmt Qual'].replace('Gd', 4)
test['Bsmt Qual'] = test['Bsmt Qual'].replace('TA', 3)
test['Bsmt Qual'] = test['Bsmt Qual'].replace('Fa', 2)
test['Bsmt Qual'] = test['Bsmt Qual'].replace('Po', 1)
test['Bsmt Qual'] = test['Bsmt Qual'].replace(np.nan, 0)

# %%
train['Bsmt Qual'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     55
# 1.0      1
# 2.0     60
# 3.0    887
# 4.0    864
# 5.0    184
# Name: Bsmt Qual, dtype: int64

# %%
test['Bsmt Qual'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     25
# 1.0      1
# 2.0     28
# 3.0    396
# 4.0    355
# 5.0     73
# Name: Bsmt Qual, dtype: int64

# %%
train['Bsmt Qual'].describe()
# Out:
# count    2051.000000
# mean        3.490005
# std         0.901637
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: Bsmt Qual, dtype: float64

# %%
test['Bsmt Qual'].describe()
# Out:
# count    878.000000
# mean       3.451025
# std        0.909468
# min        0.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Bsmt Qual, dtype: float64

# %%
train.sort_values('Bsmt Qual', inplace=True)
train['Bsmt Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Qual', inplace=True)
test['Bsmt Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Qual"])
# Out:
# <AxesSubplot:xlabel='Bsmt Qual'>

# %%
sns.boxplot(x=test["Bsmt Qual"])
# Out:
# <AxesSubplot:xlabel='Bsmt Qual'>

# %%
plt.scatter(train['Bsmt Qual'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Bsmt Cond: General condition of the basement
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Cond'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Cond'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:55|Test:25|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0

train['Bsmt Cond'] = train['Bsmt Cond'].replace('Ex', 5)
train['Bsmt Cond'] = train['Bsmt Cond'].replace('Gd', 4)
train['Bsmt Cond'] = train['Bsmt Cond'].replace('TA', 3)
train['Bsmt Cond'] = train['Bsmt Cond'].replace('Fa', 2)
train['Bsmt Cond'] = train['Bsmt Cond'].replace('Po', 1)
train['Bsmt Cond'] = train['Bsmt Cond'].replace(np.nan, 0)
test['Bsmt Cond'] = test['Bsmt Cond'].replace('Ex', 5)
test['Bsmt Cond'] = test['Bsmt Cond'].replace('Gd', 4)
test['Bsmt Cond'] = test['Bsmt Cond'].replace('TA', 3)
test['Bsmt Cond'] = test['Bsmt Cond'].replace('Fa', 2)
test['Bsmt Cond'] = test['Bsmt Cond'].replace('Po', 1)
test['Bsmt Cond'] = test['Bsmt Cond'].replace(np.nan, 0)

# %%
train['Bsmt Cond'].value_counts().sort_index(ascending=True)
# Out:
# 0.0      55
# 1.0       5
# 2.0      65
# 3.0    1834
# 4.0      89
# 5.0       3
# Name: Bsmt Cond, dtype: int64

# %%
test['Bsmt Cond'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     25
# 2.0     39
# 3.0    781
# 4.0     33
# Name: Bsmt Cond, dtype: int64

# %%
train['Bsmt Cond'].describe()
# Out:
# count    2051.000000
# mean        2.929303
# std         0.572009
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Bsmt Cond, dtype: float64

# %%
test['Bsmt Cond'].describe()
# Out:
# count    878.000000
# mean       2.907745
# std        0.574573
# min        0.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max        4.000000
# Name: Bsmt Cond, dtype: float64

# %%
train.sort_values('Bsmt Cond', inplace=True)
train['Bsmt Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Cond', inplace=True)
test['Bsmt Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Cond"])
# Out:
# <AxesSubplot:xlabel='Bsmt Cond'>

# %%
sns.boxplot(x=test["Bsmt Cond"])
# Out:
# <AxesSubplot:xlabel='Bsmt Cond'>

# %%
plt.scatter(train['Bsmt Cond'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Bsmt Exposure: Walkout or garden level basement walls
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Exposure'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Exposure'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:58|Test:25|

# %%
#Recode (Convert to rating) Gd = 3, Av = 2, Mn = 1, No = 0, NA = 0
train['Bsmt Exposure'] = train['Bsmt Exposure'].replace('Gd', 3)
train['Bsmt Exposure'] = train['Bsmt Exposure'].replace('Av', 2)
train['Bsmt Exposure'] = train['Bsmt Exposure'].replace('Mn', 1)
train['Bsmt Exposure'] = train['Bsmt Exposure'].replace('No', 0)
train['Bsmt Exposure'] = train['Bsmt Exposure'].replace(np.nan, 0)

test['Bsmt Exposure'] = test['Bsmt Exposure'].replace('Gd', 3)
test['Bsmt Exposure'] = test['Bsmt Exposure'].replace('Av', 2)
test['Bsmt Exposure'] = test['Bsmt Exposure'].replace('Mn', 1)
test['Bsmt Exposure'] = test['Bsmt Exposure'].replace('No', 0)
test['Bsmt Exposure'] = test['Bsmt Exposure'].replace(np.nan, 0)

# %%
train['Bsmt Exposure'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    1397
# 1.0     163
# 2.0     288
# 3.0     203
# Name: Bsmt Exposure, dtype: int64

# %%
test['Bsmt Exposure'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    592
# 1.0     76
# 2.0    130
# 3.0     80
# Name: Bsmt Exposure, dtype: int64

# %%
train['Bsmt Exposure'].describe()
# Out:
# count    2051.000000
# mean        0.657240
# std         1.049051
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Bsmt Exposure, dtype: float64

# %%
test['Bsmt Exposure'].describe()
# Out:
# count    878.000000
# mean       0.656036
# std        1.034261
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: Bsmt Exposure, dtype: float64

# %%
train.sort_values('Bsmt Exposure', inplace=True)
train['Bsmt Exposure'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Exposure', inplace=True)
test['Bsmt Exposure'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Exposure"])
# Out:
# <AxesSubplot:xlabel='Bsmt Exposure'>

# %%
sns.boxplot(x=test["Bsmt Exposure"])
# Out:
# <AxesSubplot:xlabel='Bsmt Exposure'>

# %%
plt.scatter(train['Bsmt Exposure'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     BsmtFin Type 1: Quality of basement finished area
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['BsmtFin Type 1'].isnull().sum()) +
                        '|Test:'+ str(test['BsmtFin Type 1'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:55|Test:25|

# %%
#Recode missing value as None
train['BsmtFin Type 1'] = train['BsmtFin Type 1'].replace(np.nan, 'None')
test['BsmtFin Type 1'] = test['BsmtFin Type 1'].replace(np.nan, 'None')

# %%
train['BsmtFin Type 1'].value_counts().sort_index(ascending=True)
# Out:
# ALQ     293
# BLQ     200
# GLQ     615
# LwQ     102
# None     55
# Rec     183
# Unf     603
# Name: BsmtFin Type 1, dtype: int64

# %%
test['BsmtFin Type 1'].value_counts().sort_index(ascending=True)
# Out:
# ALQ     136
# BLQ      69
# GLQ     243
# LwQ      52
# None     25
# Rec     105
# Unf     248
# Name: BsmtFin Type 1, dtype: int64

# %%
train.sort_values('BsmtFin Type 1', inplace=True)
train['BsmtFin Type 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('BsmtFin Type 1', inplace=True)
train['BsmtFin Type 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='BsmtFin Type 1', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='BsmtFin Type 1', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     BsmtFin SF 1: Type 1 finished square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['BsmtFin SF 1'].isnull().sum()) +
                        '|Test:'+ str(test['BsmtFin SF 1'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['BsmtFin SF 1'] = train['BsmtFin SF 1'].replace(np.nan, 0)
test['BsmtFin SF 1'] = test['BsmtFin SF 1'].replace(np.nan, 0)

# %%
train['BsmtFin SF 1'].describe()
# Out:
# count    2051.000000
# mean      442.084837
# std       461.195041
# min         0.000000
# 25%         0.000000
# 50%       368.000000
# 75%       733.500000
# max      5644.000000
# Name: BsmtFin SF 1, dtype: float64

# %%
test['BsmtFin SF 1'].describe()
# Out:
# count     878.000000
# mean      441.328018
# std       438.457329
# min         0.000000
# 25%         0.000000
# 50%       373.000000
# 75%       734.750000
# max      2288.000000
# Name: BsmtFin SF 1, dtype: float64

# %%
train.sort_values('BsmtFin SF 1', inplace=True)
train['BsmtFin SF 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('BsmtFin SF 1', inplace=True)
test['BsmtFin SF 1'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["BsmtFin SF 1"])
# Out:
# <AxesSubplot:xlabel='BsmtFin SF 1'>

# %%
sns.boxplot(x=test["BsmtFin SF 1"])
# Out:
# <AxesSubplot:xlabel='BsmtFin SF 1'>

# %%
plt.scatter(train['BsmtFin SF 1'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     BsmtFin Type2: Quality of second finished area (if present)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['BsmtFin Type 2'].isnull().sum()) +
                        '|Test:'+ str(test['BsmtFin Type 2'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:56|Test:25|

# %%
#Recode missing value as 0
train['BsmtFin Type 2'] = train['BsmtFin Type 2'].replace(np.nan, 'None')
test['BsmtFin Type 2'] = test['BsmtFin Type 2'].replace(np.nan, 'None')

# %%
train['BsmtFin Type 2'].value_counts().sort_index(ascending=True)
# Out:
# ALQ       35
# BLQ       48
# GLQ       23
# LwQ       60
# None      56
# Rec       80
# Unf     1749
# Name: BsmtFin Type 2, dtype: int64

# %%
test['BsmtFin Type 2'].value_counts().sort_index(ascending=True)
# Out:
# ALQ      18
# BLQ      20
# GLQ      11
# LwQ      29
# None     25
# Rec      26
# Unf     749
# Name: BsmtFin Type 2, dtype: int64

# %%
train.sort_values('BsmtFin Type 2', inplace=True)
train['BsmtFin Type 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('BsmtFin Type 2', inplace=True)
test['BsmtFin Type 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='BsmtFin Type 2', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='BsmtFin Type 2', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     BsmtFin SF 2: Type 2 finished square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['BsmtFin SF 2'].isnull().sum()) +
                        '|Test:'+ str(test['BsmtFin SF 2'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['BsmtFin SF 2'] = train['BsmtFin SF 2'].replace(np.nan, 0)
test['BsmtFin SF 2'] = test['BsmtFin SF 2'].replace(np.nan, 0)

# %%
train['BsmtFin SF 2'].describe()
# Out:
# count    2051.000000
# mean       47.935641
# std       164.964052
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1474.000000
# Name: BsmtFin SF 2, dtype: float64

# %%
test['BsmtFin SF 2'].describe()
# Out:
# count     878.000000
# mean       53.896355
# std       178.632355
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1526.000000
# Name: BsmtFin SF 2, dtype: float64

# %%
train.sort_values('BsmtFin SF 2', inplace=True)
train['BsmtFin SF 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('BsmtFin SF 2', inplace=True)
test['BsmtFin SF 2'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["BsmtFin SF 2"])
# Out:
# <AxesSubplot:xlabel='BsmtFin SF 2'>

# %%
sns.boxplot(x=test["BsmtFin SF 2"])
# Out:
# <AxesSubplot:xlabel='BsmtFin SF 2'>

# %%
plt.scatter(train['BsmtFin SF 2'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Bsmt Unf SF: Unfinished square feet of basement area
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Unf SF'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Unf SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['Bsmt Unf SF'] = train['Bsmt Unf SF'].replace(np.nan, 0)
test['Bsmt Unf SF'] = test['Bsmt Unf SF'].replace(np.nan, 0)

# %%
train['Bsmt Unf SF'].describe()
# Out:
# count    2051.000000
# mean      567.451487
# std       445.022846
# min         0.000000
# 25%       220.000000
# 50%       474.000000
# 75%       811.000000
# max      2336.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
test['Bsmt Unf SF'].describe()
# Out:
# count     878.000000
# mean      539.133257
# std       426.172161
# min         0.000000
# 25%       216.000000
# 50%       452.000000
# 75%       780.000000
# max      2046.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
train.sort_values('Bsmt Unf SF', inplace=True)
train['Bsmt Unf SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Unf SF', inplace=True)
test['Bsmt Unf SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Unf SF"])
# Out:
# <AxesSubplot:xlabel='Bsmt Unf SF'>

# %%
sns.boxplot(x=test["Bsmt Unf SF"])
# Out:
# <AxesSubplot:xlabel='Bsmt Unf SF'>

# %%
plt.scatter(train['Bsmt Unf SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Total Bsmt SF: Total square feet of basement area
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Total Bsmt SF'].isnull().sum()) +
                        '|Test:'+ str(test['Total Bsmt SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['Total Bsmt SF'] = train['Total Bsmt SF'].replace(np.nan, 0)
test['Total Bsmt SF'] = test['Total Bsmt SF'].replace(np.nan, 0)

# %%
train['Total Bsmt SF'].describe()
# Out:
# count    2051.000000
# mean     1057.471965
# std       449.908003
# min         0.000000
# 25%       793.000000
# 50%       994.000000
# 75%      1318.500000
# max      6110.000000
# Name: Total Bsmt SF, dtype: float64

# %%
test['Total Bsmt SF'].describe()
# Out:
# count     878.000000
# mean     1034.357631
# std       413.446291
# min         0.000000
# 25%       789.000000
# 50%       975.000000
# 75%      1247.000000
# max      2630.000000
# Name: Total Bsmt SF, dtype: float64

# %%
train.sort_values('Total Bsmt SF', inplace=True)
train['Total Bsmt SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Total Bsmt SF', inplace=True)
test['Total Bsmt SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Total Bsmt SF"])
# Out:
# <AxesSubplot:xlabel='Total Bsmt SF'>

# %%
sns.boxplot(x=test["Total Bsmt SF"])
# Out:
# <AxesSubplot:xlabel='Total Bsmt SF'>

# %%
plt.scatter(train['Total Bsmt SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Heating: Type of heating
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Heating'].isnull().sum()) +
                        '|Test:'+ str(test['Heating'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Heating'].value_counts().sort_index(ascending=True)
# Out:
# GasA    2018
# GasW      20
# Grav       5
# OthW       2
# Wall       6
# Name: Heating, dtype: int64

# %%
test['Heating'].value_counts().sort_index(ascending=True)
# Out:
# Floor      1
# GasA     866
# GasW       7
# Grav       4
# Name: Heating, dtype: int64

# %%
train.sort_values('Heating', inplace=True)
train['Heating'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Heating', inplace=True)
test['Heating'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Heating', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Heating QC: Heating quality and condition
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Heating QC'].isnull().sum()) +
                        '|Test:'+ str(test['Heating QC'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0

train['Heating QC'] = train['Heating QC'].replace('Ex', 5)
train['Heating QC'] = train['Heating QC'].replace('Gd', 4)
train['Heating QC'] = train['Heating QC'].replace('TA', 3)
train['Heating QC'] = train['Heating QC'].replace('Fa', 2)
train['Heating QC'] = train['Heating QC'].replace('Po', 1)
train['Heating QC'] = train['Heating QC'].replace(np.nan, 0)
test['Heating QC'] = test['Heating QC'].replace('Ex', 5)
test['Heating QC'] = test['Heating QC'].replace('Gd', 4)
test['Heating QC'] = test['Heating QC'].replace('TA', 3)
test['Heating QC'] = test['Heating QC'].replace('Fa', 2)
test['Heating QC'] = test['Heating QC'].replace('Po', 1)
test['Heating QC'] = test['Heating QC'].replace(np.nan, 0)

# %%
train['Heating QC'].value_counts().sort_index(ascending=True)
# Out:
# 1       3
# 2      67
# 3     597
# 4     319
# 5    1065
# Name: Heating QC, dtype: int64

# %%
test['Heating QC'].value_counts().sort_index(ascending=True)
# Out:
# 2     25
# 3    267
# 4    157
# 5    429
# Name: Heating QC, dtype: int64

# %%
train['Heating QC'].describe()
# Out:
# count    2051.000000
# mean        4.158459
# std         0.964112
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: Heating QC, dtype: float64

# %%
test['Heating QC'].describe()
# Out:
# count    878.000000
# mean       4.127563
# std        0.944113
# min        2.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: Heating QC, dtype: float64

# %%
train.sort_values('Heating QC', inplace=True)
train['Heating QC'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Heating QC', inplace=True)
test['Heating QC'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Heating QC"])
# Out:
# <AxesSubplot:xlabel='Heating QC'>

# %%
sns.boxplot(x=test["Heating QC"])
# Out:
# <AxesSubplot:xlabel='Heating QC'>

# %%
plt.scatter(train['Heating QC'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Central Air: Central air conditioning
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Central Air'].isnull().sum()) +
                        '|Test:'+ str(test['Central Air'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Central Air'].value_counts().sort_index(ascending=True)
# Out:
# N     141
# Y    1910
# Name: Central Air, dtype: int64

# %%
test['Central Air'].value_counts().sort_index(ascending=True)
# Out:
# N     55
# Y    823
# Name: Central Air, dtype: int64

# %%
train.sort_values('Central Air', inplace=True)
train['Central Air'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Central Air', inplace=True)
test['Central Air'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Central Air', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Central Air', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Electrical: Electrical system
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Electrical'].isnull().sum()) +
                        '|Test:'+ str(test['Electrical'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:1|

# %%
#Recode missing value as SBrkr
train['Electrical'] = train['Electrical'].replace(np.nan, 'SBrkr')
test['Electrical'] = test['Electrical'].replace(np.nan, 'SBrkr')

# %%
train['Electrical'].value_counts().sort_index(ascending=True)
# Out:
# FuseA     140
# FuseF      35
# FuseP       7
# Mix         1
# SBrkr    1868
# Name: Electrical, dtype: int64

# %%
test['Electrical'].value_counts().sort_index(ascending=True)
# Out:
# FuseA     48
# FuseF     15
# FuseP      1
# SBrkr    814
# Name: Electrical, dtype: int64

# %%
train.sort_values('Electrical', inplace=True)
train['Electrical'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Electrical', inplace=True)
test['Electrical'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Electrical', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     1st Flr SF: First Floor square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['1st Flr SF'].isnull().sum()) +
                        '|Test:'+ str(test['1st Flr SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['1st Flr SF'].describe()
# Out:
# count    2051.000000
# mean     1164.488055
# std       396.446923
# min       334.000000
# 25%       879.500000
# 50%      1093.000000
# 75%      1405.000000
# max      5095.000000
# Name: 1st Flr SF, dtype: float64

# %%
test['1st Flr SF'].describe()
# Out:
# count     878.000000
# mean     1145.787016
# std       375.264111
# min       407.000000
# 25%       864.000000
# 50%      1063.000000
# 75%      1358.000000
# max      2674.000000
# Name: 1st Flr SF, dtype: float64

# %%
train.sort_values('1st Flr SF', inplace=True)
train['1st Flr SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('1st Flr SF', inplace=True)
test['1st Flr SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["1st Flr SF"])
# Out:
# <AxesSubplot:xlabel='1st Flr SF'>

# %%
sns.boxplot(x=test["1st Flr SF"])
# Out:
# <AxesSubplot:xlabel='1st Flr SF'>

# %%
plt.scatter(train['1st Flr SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     2nd Flr SF: Second floor square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['2nd Flr SF'].isnull().sum()) +
                        '|Test:'+ str(test['2nd Flr SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['2nd Flr SF'].describe()
# Out:
# count    2051.000000
# mean      329.329108
# std       425.671046
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       692.500000
# max      1862.000000
# Name: 2nd Flr SF, dtype: float64

# %%
test['2nd Flr SF'].describe()
# Out:
# count     878.000000
# mean      348.398633
# std       432.985566
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       720.000000
# max      2065.000000
# Name: 2nd Flr SF, dtype: float64

# %%
train.sort_values('2nd Flr SF', inplace=True)
train['2nd Flr SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('2nd Flr SF', inplace=True)
test['2nd Flr SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["2nd Flr SF"])
# Out:
# <AxesSubplot:xlabel='2nd Flr SF'>

# %%
sns.boxplot(x=test["2nd Flr SF"])
# Out:
# <AxesSubplot:xlabel='2nd Flr SF'>

# %%
plt.scatter(train['2nd Flr SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Low Qual Fin SF: Low quality finished square feet (all floors)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Low Qual Fin SF'].isnull().sum()) +
                        '|Test:'+ str(test['Low Qual Fin SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Low Qual Fin SF'].describe()
# Out:
# count    2051.000000
# mean        5.512921
# std        51.068870
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1064.000000
# Name: Low Qual Fin SF, dtype: float64

# %%
test['Low Qual Fin SF'].describe()
# Out:
# count    878.000000
# mean       2.728929
# std       32.572548
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      481.000000
# Name: Low Qual Fin SF, dtype: float64

# %%
train.sort_values('Low Qual Fin SF', inplace=True)
train['Low Qual Fin SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Low Qual Fin SF', inplace=True)
test['Low Qual Fin SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Low Qual Fin SF"])
# Out:
# <AxesSubplot:xlabel='Low Qual Fin SF'>

# %%
sns.boxplot(x=test["Low Qual Fin SF"])
# Out:
# <AxesSubplot:xlabel='Low Qual Fin SF'>

# %%
plt.scatter(train['Low Qual Fin SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Gr Liv Area: Above grade (ground) living area square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Gr Liv Area'].isnull().sum()) +
                        '|Test:'+ str(test['Gr Liv Area'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Gr Liv Area'].describe()
# Out:
# count    2051.000000
# mean     1499.330083
# std       500.447829
# min       334.000000
# 25%      1129.000000
# 50%      1444.000000
# 75%      1728.500000
# max      5642.000000
# Name: Gr Liv Area, dtype: float64

# %%
test['Gr Liv Area'].describe()
# Out:
# count     878.000000
# mean     1496.914579
# std       506.468967
# min       407.000000
# 25%      1114.000000
# 50%      1436.000000
# 75%      1779.000000
# max      4476.000000
# Name: Gr Liv Area, dtype: float64

# %%
train.sort_values('Gr Liv Area', inplace=True)
train['Gr Liv Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Gr Liv Area', inplace=True)
test['Gr Liv Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Gr Liv Area"])
# Out:
# <AxesSubplot:xlabel='Gr Liv Area'>

# %%
sns.boxplot(x=test["Gr Liv Area"])
# Out:
# <AxesSubplot:xlabel='Gr Liv Area'>

# %%
plt.scatter(train['Gr Liv Area'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Bsmt Full Bath: Basement full bathrooms
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Full Bath'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Full Bath'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:2|Test:0|

# %%
#Recode missing value as 0
train['Bsmt Full Bath'] = train['Bsmt Full Bath'].replace(np.nan, 0)
test['Bsmt Full Bath'] = test['Bsmt Full Bath'].replace(np.nan, 0)

# %%
train['Bsmt Full Bath'].describe()
# Out:
# count    2051.000000
# mean        0.427109
# std         0.522589
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Bsmt Full Bath, dtype: float64

# %%
test['Bsmt Full Bath'].describe()
# Out:
# count    878.000000
# mean       0.439636
# std        0.529948
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        2.000000
# Name: Bsmt Full Bath, dtype: float64

# %%
train.sort_values('Bsmt Full Bath', inplace=True)
train['Bsmt Full Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Full Bath', inplace=True)
test['Bsmt Full Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Full Bath"])
# Out:
# <AxesSubplot:xlabel='Bsmt Full Bath'>

# %%
sns.boxplot(x=test["Bsmt Full Bath"])
# Out:
# <AxesSubplot:xlabel='Bsmt Full Bath'>

# %%
plt.scatter(train['Bsmt Full Bath'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Bsmt Half Bath: Basement half bathrooms
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bsmt Half Bath'].isnull().sum()) +
                        '|Test:'+ str(test['Bsmt Half Bath'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:2|Test:0|

# %%
#Recode missing value as 0
train['Bsmt Half Bath'] = train['Bsmt Half Bath'].replace(np.nan, 0)
test['Bsmt Half Bath'] = test['Bsmt Half Bath'].replace(np.nan, 0)

# %%
train['Bsmt Half Bath'].value_counts()
# Out:
# 0.0    1925
# 1.0     122
# 2.0       4
# Name: Bsmt Half Bath, dtype: int64

# %%
test['Bsmt Half Bath'].value_counts()
# Out:
# 0    829
# 1     49
# Name: Bsmt Half Bath, dtype: int64

# %%
train['Bsmt Half Bath'].describe()
# Out:
# count    2051.000000
# mean        0.063384
# std         0.251590
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: Bsmt Half Bath, dtype: float64

# %%
test['Bsmt Half Bath'].describe()
# Out:
# count    878.000000
# mean       0.055809
# std        0.229683
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: Bsmt Half Bath, dtype: float64

# %%
train.sort_values('Bsmt Half Bath', inplace=True)
train['Bsmt Half Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bsmt Half Bath', inplace=True)
test['Bsmt Half Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bsmt Half Bath"])
# Out:
# <AxesSubplot:xlabel='Bsmt Half Bath'>

# %%
sns.boxplot(x=test["Bsmt Half Bath"])
# Out:
# <AxesSubplot:xlabel='Bsmt Half Bath'>

# %%
plt.scatter(train['Bsmt Half Bath'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Full Bath: Full bathrooms above grade
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Full Bath'].isnull().sum()) +
                        '|Test:'+ str(test['Full Bath'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Full Bath'].value_counts()
# Out:
# 2    1096
# 1     900
# 3      45
# 0       8
# 4       2
# Name: Full Bath, dtype: int64

# %%
test['Full Bath'].value_counts()
# Out:
# 2    436
# 1    418
# 3     18
# 0      4
# 4      2
# Name: Full Bath, dtype: int64

# %%
train['Full Bath'].describe()
# Out:
# count    2051.000000
# mean        1.577279
# std         0.549279
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Full Bath, dtype: float64

# %%
test['Full Bath'].describe()
# Out:
# count    878.000000
# mean       1.539863
# std        0.559060
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: Full Bath, dtype: float64

# %%
train.sort_values('Full Bath', inplace=True)
train['Full Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Full Bath', inplace=True)
test['Full Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Full Bath"])
# Out:
# <AxesSubplot:xlabel='Full Bath'>

# %%
sns.boxplot(x=test["Full Bath"])
# Out:
# <AxesSubplot:xlabel='Full Bath'>

# %%
plt.scatter(train['Full Bath'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Half Bath: Half baths above grade
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Half Bath'].isnull().sum()) +
                        '|Test:'+ str(test['Half Bath'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Half Bath'].value_counts()
# Out:
# 0    1308
# 1     725
# 2      18
# Name: Half Bath, dtype: int64

# %%
test['Half Bath'].value_counts()
# Out:
# 0    535
# 1    336
# 2      7
# Name: Half Bath, dtype: int64

# %%
train['Half Bath'].describe()
# Out:
# count    2051.000000
# mean        0.371039
# std         0.501043
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         2.000000
# Name: Half Bath, dtype: float64

# %%
test['Half Bath'].describe()
# Out:
# count    878.000000
# mean       0.398633
# std        0.505927
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        2.000000
# Name: Half Bath, dtype: float64

# %%
train.sort_values('Half Bath', inplace=True)
train['Half Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Half Bath', inplace=True)
test['Half Bath'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Half Bath"])
# Out:
# <AxesSubplot:xlabel='Half Bath'>

# %%
sns.boxplot(x=test["Half Bath"])
# Out:
# <AxesSubplot:xlabel='Half Bath'>

# %%
plt.scatter(train['Half Bath'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Bedroom AbvGr: Number of bedrooms above basement level
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Bedroom AbvGr'].isnull().sum()) +
                        '|Test:'+ str(test['Bedroom AbvGr'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Bedroom AbvGr'].value_counts().sort_index(ascending=True)
# Out:
# 0       5
# 1      75
# 2     544
# 3    1108
# 4     265
# 5      41
# 6      12
# 8       1
# Name: Bedroom AbvGr, dtype: int64

# %%
test['Bedroom AbvGr'].value_counts().sort_index(ascending=True)
# Out:
# 0      3
# 1     37
# 2    199
# 3    488
# 4    135
# 5      7
# 6      9
# Name: Bedroom AbvGr, dtype: int64

# %%
train['Bedroom AbvGr'].describe()
# Out:
# count    2051.000000
# mean        2.843491
# std         0.826618
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# Name: Bedroom AbvGr, dtype: float64

# %%
test['Bedroom AbvGr'].describe()
# Out:
# count    878.000000
# mean       2.879271
# std        0.830712
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        6.000000
# Name: Bedroom AbvGr, dtype: float64

# %%
train.sort_values('Bedroom AbvGr', inplace=True)
train['Bedroom AbvGr'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Bedroom AbvGr', inplace=True)
test['Bedroom AbvGr'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Bedroom AbvGr"])
# Out:
# <AxesSubplot:xlabel='Bedroom AbvGr'>

# %%
sns.boxplot(x=test["Bedroom AbvGr"])
# Out:
# <AxesSubplot:xlabel='Bedroom AbvGr'>

# %%
plt.scatter(train['Bedroom AbvGr'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Kitchen AbvGr: Number of kitchens
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Kitchen AbvGr'].isnull().sum()) +
                        '|Test:'+ str(test['Kitchen AbvGr'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Kitchen AbvGr'].value_counts().sort_index(ascending=True)
# Out:
# 0       2
# 1    1960
# 2      88
# 3       1
# Name: Kitchen AbvGr, dtype: int64

# %%
test['Kitchen AbvGr'].value_counts().sort_index(ascending=True)
# Out:
# 0      1
# 1    835
# 2     41
# 3      1
# Name: Kitchen AbvGr, dtype: int64

# %%
train['Kitchen AbvGr'].describe()
# Out:
# count    2051.000000
# mean        1.042906
# std         0.209790
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: Kitchen AbvGr, dtype: float64

# %%
test['Kitchen AbvGr'].describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# count    878.000000
# mean       1.047836
# std        0.223966
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: Kitchen AbvGr, dtype: float64

# %%
train.sort_values('Kitchen AbvGr', inplace=True)
train['Kitchen AbvGr'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Kitchen AbvGr', inplace=True)
test['Kitchen AbvGr'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Kitchen AbvGr"])
# Out:
# <AxesSubplot:xlabel='Kitchen AbvGr'>

# %%
sns.boxplot(x=test["Kitchen AbvGr"])
# Out:
# <AxesSubplot:xlabel='Kitchen AbvGr'>

# %%
plt.scatter(train['Kitchen AbvGr'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Kitchen Qual: Kitchen quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Kitchen Qual'].isnull().sum()) +
                        '|Test:'+ str(test['Kitchen Qual'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1

train['Kitchen Qual'] = train['Kitchen Qual'].replace('Ex', 5)
train['Kitchen Qual'] = train['Kitchen Qual'].replace('Gd', 4)
train['Kitchen Qual'] = train['Kitchen Qual'].replace('TA', 3)
train['Kitchen Qual'] = train['Kitchen Qual'].replace('Fa', 2)
train['Kitchen Qual'] = train['Kitchen Qual'].replace('Po', 1)
test['Kitchen Qual'] = test['Kitchen Qual'].replace('Ex', 5)
test['Kitchen Qual'] = test['Kitchen Qual'].replace('Gd', 4)
test['Kitchen Qual'] = test['Kitchen Qual'].replace('TA', 3)
test['Kitchen Qual'] = test['Kitchen Qual'].replace('Fa', 2)
test['Kitchen Qual'] = test['Kitchen Qual'].replace('Po', 1)

# %%
train['Kitchen Qual'].value_counts().sort_index(ascending=True)
# Out:
# 2      47
# 3    1047
# 4     806
# 5     151
# Name: Kitchen Qual, dtype: int64

# %%
test['Kitchen Qual'].value_counts().sort_index(ascending=True)
# Out:
# 1      1
# 2     23
# 3    447
# 4    354
# 5     53
# Name: Kitchen Qual, dtype: int64

# %%
train['Kitchen Qual'].describe()
# Out:
# count    2051.000000
# mean        3.517309
# std         0.665577
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Kitchen Qual, dtype: float64

# %%
test['Kitchen Qual'].describe()
# Out:
# count    878.000000
# mean       3.495444
# std        0.656067
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Kitchen Qual, dtype: float64

# %%
train.sort_values('Kitchen Qual', inplace=True)
train['Kitchen Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Kitchen Qual', inplace=True)
test['Kitchen Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Kitchen Qual"])
# Out:
# <AxesSubplot:xlabel='Kitchen Qual'>

# %%
sns.boxplot(x=test['Kitchen Qual'])
# Out:
# <AxesSubplot:xlabel='Kitchen Qual'>

# %%
plt.scatter(train['Kitchen Qual'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     TotRms AbvGrd: Total rooms above grade (does not include bathrooms)
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['TotRms AbvGrd'].isnull().sum()) +
                        '|Test:'+ str(test['TotRms AbvGrd'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['TotRms AbvGrd'].describe()
# Out:
# count    2051.000000
# mean        6.435885
# std         1.560225
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        15.000000
# Name: TotRms AbvGrd, dtype: float64

# %%
test['TotRms AbvGrd'].describe()
# Out:
# count    878.000000
# mean       6.454442
# std        1.596632
# min        3.000000
# 25%        5.000000
# 50%        6.000000
# 75%        7.000000
# max       12.000000
# Name: TotRms AbvGrd, dtype: float64

# %%
train.sort_values('TotRms AbvGrd', inplace=True)
train['TotRms AbvGrd'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('TotRms AbvGrd', inplace=True)
test['TotRms AbvGrd'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["TotRms AbvGrd"])
# Out:
# <AxesSubplot:xlabel='TotRms AbvGrd'>

# %%
sns.boxplot(x=test["TotRms AbvGrd"])
# Out:
# <AxesSubplot:xlabel='TotRms AbvGrd'>

# %%
plt.scatter(train['TotRms AbvGrd'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Functional: Home functionality rating
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Functional'].isnull().sum()) +
                        '|Test:'+ str(test['Functional'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Functional'].value_counts().sort_index(ascending=True)
# Out:
# Maj1      12
# Maj2       7
# Min1      42
# Min2      42
# Mod       29
# Sal        2
# Sev        2
# Typ     1915
# Name: Functional, dtype: int64

# %%
test['Functional'].value_counts().sort_index(ascending=True)
# Out:
# Maj1      7
# Maj2      2
# Min1     23
# Min2     28
# Mod       6
# Typ     812
# Name: Functional, dtype: int64

# %%
train.sort_values('Functional', inplace=True)
train['Functional'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Functional', inplace=True)
test['Functional'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
train.groupby('Functional')['SalePrice'].describe()
# Out:
#              count           mean           std      min       25%       50%  \
# Functional
# Maj1          12.0  163106.166667  54563.184907  61000.0  133000.0  147700.0
# Maj2           7.0   87157.714286  37181.726469  52000.0   66000.0   68104.0
# Min1          42.0  154429.761905  48195.569336  57625.0  127750.0  148250.0
# Min2          42.0  150424.571429  52177.996640  63900.0  118500.0  143400.0
# Mod           29.0  148108.724138  92052.265979  51689.0  107500.0  128000.0
# Sal            2.0   31550.000000  26092.240226  13100.0   22325.0   31550.0
# Sev            2.0   95750.000000  47022.600949  62500.0   79125.0   95750.0
# Typ         1915.0  183954.749347  79669.717839  12789.0  130000.0  165000.0
#
#                   75%       max
# Functional
# Maj1        200531.00  275000.0
# Maj2        100000.00  158000.0
# Min1        177343.75  315000.0
# Min2        164612.50  316600.0
# Mod         155000.00  538000.0
# Sal          40775.00   50000.0
# ...

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Fireplaces: Number of fireplaces
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Fireplaces'].isnull().sum()) +
                        '|Test:'+ str(test['Fireplaces'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Fireplaces'].value_counts().sort_index(ascending=True)
# Out:
# 0    1000
# 1     898
# 2     146
# 3       6
# 4       1
# Name: Fireplaces, dtype: int64

# %%
test['Fireplaces'].value_counts().sort_index(ascending=True)
# Out:
# 0    422
# 1    375
# 2     75
# 3      6
# Name: Fireplaces, dtype: int64

# %%
train['Fireplaces'].describe()
# Out:
# count    2051.000000
# mean        0.590931
# std         0.638516
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: Fireplaces, dtype: float64

# %%
test['Fireplaces'].describe()
# Out:
# count    878.000000
# mean       0.618451
# std        0.669571
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: Fireplaces, dtype: float64

# %%
train.sort_values('Fireplaces', inplace=True)
train['Fireplaces'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Fireplaces', inplace=True)
test['Fireplaces'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Fireplaces"])
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
sns.boxplot(x=test["Fireplaces"])
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
plt.scatter(train['Fireplaces'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Fireplace Qu: Fireplace quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Fireplace Qu'].isnull().sum()) +
                        '|Test:'+ str(test['Fireplace Qu'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1000|Test:422|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NaN = 0

train['Fireplace Qu'] = train['Fireplace Qu'].replace('Ex', 5)
train['Fireplace Qu'] = train['Fireplace Qu'].replace('Gd', 4)
train['Fireplace Qu'] = train['Fireplace Qu'].replace('TA', 3)
train['Fireplace Qu'] = train['Fireplace Qu'].replace('Fa', 2)
train['Fireplace Qu'] = train['Fireplace Qu'].replace('Po', 1)
train['Fireplace Qu'] = train['Fireplace Qu'].replace(np.nan, 0)
test['Fireplace Qu'] = test['Fireplace Qu'].replace('Ex', 5)
test['Fireplace Qu'] = test['Fireplace Qu'].replace('Gd', 4)
test['Fireplace Qu'] = test['Fireplace Qu'].replace('TA', 3)
test['Fireplace Qu'] = test['Fireplace Qu'].replace('Fa', 2)
test['Fireplace Qu'] = test['Fireplace Qu'].replace('Po', 1)
test['Fireplace Qu'] = test['Fireplace Qu'].replace(np.nan, 0)

# %%
train['Fireplace Qu'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    1000
# 1.0      31
# 2.0      59
# 3.0     407
# 4.0     523
# 5.0      31
# Name: Fireplace Qu, dtype: int64

# %%
test['Fireplace Qu'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    422
# 1.0     15
# 2.0     16
# 3.0    193
# 4.0    220
# 5.0     12
# Name: Fireplace Qu, dtype: int64

# %%
train['Fireplace Qu'].describe()
# Out:
# count    2051.000000
# mean        1.763530
# std         1.807074
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max         5.000000
# Name: Fireplace Qu, dtype: float64

# %%
test['Fireplace Qu'].describe()
# Out:
# count    878.000000
# mean       1.783599
# std        1.800445
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        4.000000
# max        5.000000
# Name: Fireplace Qu, dtype: float64

# %%
train.sort_values('Fireplace Qu', inplace=True)
train['Fireplace Qu'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Fireplace Qu', inplace=True)
test['Fireplace Qu'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Fireplace Qu', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Fireplace Qu', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Garage Type: Garage location
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Type'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Type'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:113|Test:44|

# %%
#Recode missing value as None
train['Garage Type'] = train['Garage Type'].replace(np.nan, 'None')
test['Garage Type'] = test['Garage Type'].replace(np.nan, 'None')

# %%
train['Garage Type'].value_counts().sort_index(ascending=True)
# Out:
# 2Types       19
# Attchd     1213
# Basment      27
# BuiltIn     132
# CarPort      11
# Detchd      536
# None        113
# Name: Garage Type, dtype: int64

# %%
test['Garage Type'].value_counts().sort_index(ascending=True)
# Out:
# 2Types       4
# Attchd     518
# Basment      9
# BuiltIn     53
# CarPort      4
# Detchd     246
# None        44
# Name: Garage Type, dtype: int64

# %%
train.sort_values('Garage Type', inplace=True)
train['Garage Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Type', inplace=True)
test['Garage Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Garage Type', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Garage Type', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Garage Yr Blt: Year garage was built
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Yr Blt'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Yr Blt'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:114|Test:45|

# %%
#replace 2207 to 2007
train['Garage Yr Blt'] = train['Garage Yr Blt'].replace(2207, 2007)

# %%
train['Garage Yr Blt'].describe()
# Out:
# count    1937.000000
# mean     1978.604543
# std        24.914493
# min      1895.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
test['Garage Yr Blt'].describe()
# Out:
# count     833.000000
# mean     1976.759904
# std        25.689763
# min      1900.000000
# 25%      1960.000000
# 50%      1978.000000
# 75%      2001.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
train.sort_values('Garage Yr Blt', inplace=True)
train['Garage Yr Blt'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Yr Blt', inplace=True)
test['Garage Yr Blt'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Garage Yr Blt"])
# Out:
# <AxesSubplot:xlabel='Garage Yr Blt'>

# %%
sns.boxplot(x=test["Garage Yr Blt"])
# Out:
# <AxesSubplot:xlabel='Garage Yr Blt'>

# %%
plt.scatter(train['Garage Yr Blt'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Garage Finish: Interior finish of the garage
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Finish'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Finish'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:114|Test:45|

# %%
#Recode missing value as None
train['Garage Finish'] = train['Garage Finish'].replace(np.nan, 'None')
test['Garage Finish'] = test['Garage Finish'].replace(np.nan, 'None')

# %%
train['Garage Finish'].value_counts().sort_index(ascending=True)
# Out:
# Fin     509
# None    114
# RFn     579
# Unf     849
# Name: Garage Finish, dtype: int64

# %%
test['Garage Finish'].value_counts().sort_index(ascending=True)
# Out:
# Fin     218
# None     45
# RFn     233
# Unf     382
# Name: Garage Finish, dtype: int64

# %%
train.sort_values('Garage Finish', inplace=True)
train['Garage Finish'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Finish', inplace=True)
test['Garage Finish'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Garage Finish', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Garage Finish', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Garage Cars: Size of garage in car capacity
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Cars'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Cars'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['Garage Cars'] = train['Garage Cars'].replace(np.nan, 0)
test['Garage Cars'] = test['Garage Cars'].replace(np.nan, 0)

# %%
train['Garage Cars'].describe()
# Out:
# count    2051.000000
# mean        1.775719
# std         0.765357
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: Garage Cars, dtype: float64

# %%
test['Garage Cars'].describe()
# Out:
# count    878.000000
# mean       1.742597
# std        0.750391
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: Garage Cars, dtype: float64

# %%
train.sort_values('Garage Cars', inplace=True)
train['Garage Cars'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Cars', inplace=True)
test['Garage Cars'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Garage Cars"])
# Out:
# <AxesSubplot:xlabel='Garage Cars'>

# %%
sns.boxplot(x=test["Garage Cars"])
# Out:
# <AxesSubplot:xlabel='Garage Cars'>

# %%
plt.scatter(train['Garage Cars'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Garage Area: Size of garage in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Area'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Area'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1|Test:0|

# %%
#Recode missing value as 0
train['Garage Area'] = train['Garage Area'].replace(np.nan, 0)
test['Garage Area'] = test['Garage Area'].replace(np.nan, 0)

# %%
train['Garage Area'].describe()
# Out:
# count    2051.000000
# mean      473.440761
# std       216.135102
# min         0.000000
# 25%       319.000000
# 50%       480.000000
# 75%       576.000000
# max      1418.000000
# Name: Garage Area, dtype: float64

# %%
test['Garage Area'].describe()
# Out:
# count     878.000000
# mean      470.362187
# std       212.734075
# min         0.000000
# 25%       322.500000
# 50%       473.000000
# 75%       576.000000
# max      1488.000000
# Name: Garage Area, dtype: float64

# %%
train.sort_values('Garage Area', inplace=True)
train['Garage Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Area', inplace=True)
test['Garage Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Garage Area"])
# Out:
# <AxesSubplot:xlabel='Garage Area'>

# %%
sns.boxplot(x=test["Garage Area"])
# Out:
# <AxesSubplot:xlabel='Garage Area'>

# %%
plt.scatter(train['Garage Area'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Garage Qual: Garage quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Qual'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Qual'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:114|Test:45|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0
train['Garage Qual'] = train['Garage Qual'].replace('Ex', 5)
train['Garage Qual'] = train['Garage Qual'].replace('Gd', 4)
train['Garage Qual'] = train['Garage Qual'].replace('TA', 3)
train['Garage Qual'] = train['Garage Qual'].replace('Fa', 2)
train['Garage Qual'] = train['Garage Qual'].replace('Po', 1)
train['Garage Qual'] = train['Garage Qual'].replace(np.nan, 0)
test['Garage Qual'] = test['Garage Qual'].replace('Ex', 5)
test['Garage Qual'] = test['Garage Qual'].replace('Gd', 4)
test['Garage Qual'] = test['Garage Qual'].replace('TA', 3)
test['Garage Qual'] = test['Garage Qual'].replace('Fa', 2)
test['Garage Qual'] = test['Garage Qual'].replace('Po', 1)
test['Garage Qual'] = test['Garage Qual'].replace(np.nan, 0)

# %%
train['Garage Qual'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     114
# 1.0       2
# 2.0      82
# 3.0    1832
# 4.0      18
# 5.0       3
# Name: Garage Qual, dtype: int64

# %%
test['Garage Qual'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     45
# 1.0      3
# 2.0     42
# 3.0    782
# 4.0      6
# Name: Garage Qual, dtype: int64

# %%
train['Garage Qual'].describe()
# Out:
# count    2051.000000
# mean        2.803023
# std         0.721253
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Garage Qual, dtype: float64

# %%
test['Garage Qual'].describe()
# Out:
# count    878.000000
# mean       2.798405
# std        0.699664
# min        0.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max        4.000000
# Name: Garage Qual, dtype: float64

# %%
train.sort_values('Garage Qual', inplace=True)
train['Garage Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Qual', inplace=True)
test['Garage Qual'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train['Garage Qual'])
# Out:
# <AxesSubplot:xlabel='Garage Qual'>

# %%
sns.boxplot(x=test['Garage Qual'])
# Out:
# <AxesSubplot:xlabel='Garage Qual'>

# %%
plt.scatter(train['Garage Qual'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Garage Cond: Garage condition
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Garage Cond'].isnull().sum()) +
                        '|Test:'+ str(test['Garage Cond'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:114|Test:45|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0

train['Garage Cond'] = train['Garage Cond'].replace('Ex', 5)
train['Garage Cond'] = train['Garage Cond'].replace('Gd', 4)
train['Garage Cond'] = train['Garage Cond'].replace('TA', 3)
train['Garage Cond'] = train['Garage Cond'].replace('Fa', 2)
train['Garage Cond'] = train['Garage Cond'].replace('Po', 1)
train['Garage Cond'] = train['Garage Cond'].replace(np.nan, 0)
test['Garage Cond'] = test['Garage Cond'].replace('Ex', 5)
test['Garage Cond'] = test['Garage Cond'].replace('Gd', 4)
test['Garage Cond'] = test['Garage Cond'].replace('TA', 3)
test['Garage Cond'] = test['Garage Cond'].replace('Fa', 2)
test['Garage Cond'] = test['Garage Cond'].replace('Po', 1)
test['Garage Cond'] = test['Garage Cond'].replace(np.nan, 0)

# %%
train['Garage Cond'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     114
# 1.0       8
# 2.0      47
# 3.0    1868
# 4.0      12
# 5.0       2
# Name: Garage Cond, dtype: int64

# %%
test['Garage Cond'].value_counts().sort_index(ascending=True)
# Out:
# 0.0     45
# 1.0      6
# 2.0     27
# 3.0    796
# 4.0      3
# 5.0      1
# Name: Garage Cond, dtype: int64

# %%
train['Garage Cond'].describe()
# Out:
# count    2051.000000
# mean        2.810336
# std         0.716094
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Garage Cond, dtype: float64

# %%
test['Garage Cond'].describe()
# Out:
# count    878.000000
# mean       2.807517
# std        0.700603
# min        0.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Garage Cond, dtype: float64

# %%
train.sort_values('Garage Cond', inplace=True)
train['Garage Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Garage Cond', inplace=True)
test['Garage Cond'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Garage Cond"])
# Out:
# <AxesSubplot:xlabel='Garage Cond'>

# %%
sns.boxplot(x=test["Garage Cond"])
# Out:
# <AxesSubplot:xlabel='Garage Cond'>

# %%
plt.scatter(train['Garage Cond'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Paved Drive: Paved driveway
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Paved Drive'].isnull().sum()) +
                        '|Test:'+ str(test['Paved Drive'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Paved Drive'].value_counts().sort_index(ascending=True)
# Out:
# N     151
# P      39
# Y    1861
# Name: Paved Drive, dtype: int64

# %%
test['Paved Drive'].value_counts().sort_index(ascending=True)
# Out:
# N     65
# P     23
# Y    790
# Name: Paved Drive, dtype: int64

# %%
train.sort_values('Paved Drive', inplace=True)
train['Paved Drive'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Paved Drive', inplace=True)
test['Paved Drive'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Paved Drive', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Paved Drive', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Wood Deck SF: Wood deck area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Wood Deck SF'].isnull().sum()) +
                        '|Test:'+ str(test['Wood Deck SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Wood Deck SF'].describe()
# Out:
# count    2051.000000
# mean       93.833740
# std       128.549416
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       168.000000
# max      1424.000000
# Name: Wood Deck SF, dtype: float64

# %%
test['Wood Deck SF'].describe()
# Out:
# count    878.000000
# mean      93.430524
# std      121.181702
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      170.750000
# max      690.000000
# Name: Wood Deck SF, dtype: float64

# %%
train.sort_values('Wood Deck SF', inplace=True)
train['Wood Deck SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Wood Deck SF', inplace=True)
test['Wood Deck SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Wood Deck SF"])
# Out:
# <AxesSubplot:xlabel='Wood Deck SF'>

# %%
sns.boxplot(x=test["Wood Deck SF"])
# Out:
# <AxesSubplot:xlabel='Wood Deck SF'>

# %%
plt.scatter(train['Wood Deck SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Open Porch SF: Open porch area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Open Porch SF'].isnull().sum()) +
                        '|Test:'+ str(test['Open Porch SF'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Open Porch SF'].describe()
# Out:
# count    2051.000000
# mean       47.556802
# std        66.747241
# min         0.000000
# 25%         0.000000
# 50%        27.000000
# 75%        70.000000
# max       547.000000
# Name: Open Porch SF, dtype: float64

# %%
test['Open Porch SF'].describe()
# Out:
# count    878.000000
# mean      47.070615
# std       68.180939
# min        0.000000
# 25%        0.000000
# 50%       27.000000
# 75%       69.750000
# max      742.000000
# Name: Open Porch SF, dtype: float64

# %%
train.sort_values('Open Porch SF', inplace=True)
train['Open Porch SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Open Porch SF', inplace=True)
test['Open Porch SF'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Open Porch SF"])
# Out:
# <AxesSubplot:xlabel='Open Porch SF'>

# %%
sns.boxplot(x=test["Open Porch SF"])
# Out:
# <AxesSubplot:xlabel='Open Porch SF'>

# %%
plt.scatter(train['Open Porch SF'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Enclosed Porch: Enclosed porch area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Enclosed Porch'].isnull().sum()) +
                        '|Test:'+ str(test['Enclosed Porch'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Enclosed Porch'].describe()
# Out:
# count    2051.000000
# mean       22.571916
# std        59.845110
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       432.000000
# Name: Enclosed Porch, dtype: float64

# %%
test['Enclosed Porch'].describe()
# Out:
# count     878.000000
# mean       24.064920
# std        73.249463
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1012.000000
# Name: Enclosed Porch, dtype: float64

# %%
train.sort_values('Enclosed Porch', inplace=True)
train['Enclosed Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Enclosed Porch', inplace=True)
test['Enclosed Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Enclosed Porch"])
# Out:
# <AxesSubplot:xlabel='Enclosed Porch'>

# %%
sns.boxplot(x=test["Enclosed Porch"])
# Out:
# <AxesSubplot:xlabel='Enclosed Porch'>

# %%
plt.scatter(train['Enclosed Porch'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     3Ssn Porch: Three season porch area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['3Ssn Porch'].isnull().sum()) +
                        '|Test:'+ str(test['3Ssn Porch'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['3Ssn Porch'].describe()
# Out:
# count    2051.000000
# mean        2.591419
# std        25.229615
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       508.000000
# Name: 3Ssn Porch, dtype: float64

# %%
test['3Ssn Porch'].describe()
# Out:
# count    878.000000
# mean       2.597950
# std       24.962482
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      360.000000
# Name: 3Ssn Porch, dtype: float64

# %%
train.sort_values('3Ssn Porch', inplace=True)
train['3Ssn Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('3Ssn Porch', inplace=True)
test['3Ssn Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["3Ssn Porch"])
# Out:
# <AxesSubplot:xlabel='3Ssn Porch'>

# %%
sns.boxplot(x=test["3Ssn Porch"])
# Out:
# <AxesSubplot:xlabel='3Ssn Porch'>

# %%
plt.scatter(train['3Ssn Porch'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Screen Porch: Screen porch area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Screen Porch'].isnull().sum()) +
                        '|Test:'+ str(test['Screen Porch'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Screen Porch'].describe()
# Out:
# count    2051.000000
# mean       16.511458
# std        57.374204
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       490.000000
# Name: Screen Porch, dtype: float64

# %%
test['Screen Porch'].describe()
# Out:
# count    878.000000
# mean      14.830296
# std       53.003794
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      576.000000
# Name: Screen Porch, dtype: float64

# %%
train.sort_values('Screen Porch', inplace=True)
train['Screen Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Screen Porch', inplace=True)
test['Screen Porch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Screen Porch"])
# Out:
# <AxesSubplot:xlabel='Screen Porch'>

# %%
sns.boxplot(x=test["Screen Porch"])
# Out:
# <AxesSubplot:xlabel='Screen Porch'>

# %%
plt.scatter(train['Screen Porch'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Pool Area: Pool area in square feet
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Pool Area'].isnull().sum()) +
                        '|Test:'+ str(test['Pool Area'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Pool Area'].describe()
# Out:
# count    2051.000000
# mean        2.397855
# std        37.782570
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       800.000000
# Name: Pool Area, dtype: float64

# %%
test['Pool Area'].describe()
# Out:
# count    878.000000
# mean       1.884966
# std       29.916672
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      555.000000
# Name: Pool Area, dtype: float64

# %%
train.sort_values('Pool Area', inplace=True)
train['Pool Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Pool Area', inplace=True)
test['Pool Area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train['Pool Area'])
# Out:
# <AxesSubplot:xlabel='Pool Area'>

# %%
sns.boxplot(x=test['Pool Area'])
# Out:
# <AxesSubplot:xlabel='Pool Area'>

# %%
plt.scatter(train['Pool Area'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical/Scale]</font>
#     Pool QC: Pool quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Pool QC'].isnull().sum()) +
                        '|Test:'+ str(test['Pool QC'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:2042|Test:874|

# %%
#Recode (Convert to rating) Ex = 5, Gd = 4, TA = 3, Fa = 2, Po = 1, NA = 0

train['Pool QC'] = train['Pool QC'].replace('Ex', 5)
train['Pool QC'] = train['Pool QC'].replace('Gd', 4)
train['Pool QC'] = train['Pool QC'].replace('TA', 3)
train['Pool QC'] = train['Pool QC'].replace('Fa', 2)
train['Pool QC'] = train['Pool QC'].replace('Po', 1)
train['Pool QC'] = train['Pool QC'].replace(np.nan, 0)
test['Pool QC'] = test['Pool QC'].replace('Ex', 5)
test['Pool QC'] = test['Pool QC'].replace('Gd', 4)
test['Pool QC'] = test['Pool QC'].replace('TA', 3)
test['Pool QC'] = test['Pool QC'].replace('Fa', 2)
test['Pool QC'] = test['Pool QC'].replace('Po', 1)
test['Pool QC'] = test['Pool QC'].replace(np.nan, 0)

# %%
train['Pool QC'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    2042
# 2.0       2
# 3.0       2
# 4.0       4
# 5.0       1
# Name: Pool QC, dtype: int64

# %%
test['Pool QC'].value_counts().sort_index(ascending=True)
# Out:
# 0.0    874
# 3.0      1
# 5.0      3
# Name: Pool QC, dtype: int64

# %%
train['Pool QC'].describe()
# Out:
# count    2051.000000
# mean        0.015115
# std         0.236366
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         5.000000
# Name: Pool QC, dtype: float64

# %%
test['Pool QC'].describe()
# Out:
# count    878.000000
# mean       0.020501
# std        0.308805
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        5.000000
# Name: Pool QC, dtype: float64

# %%
train.sort_values('Pool QC', inplace=True)
train['Pool QC'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Pool QC', inplace=True)
test['Pool QC'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Pool QC"])
# Out:
# <AxesSubplot:xlabel='Pool QC'>

# %%
sns.boxplot(x=test["Pool QC"])
# Out:
# <AxesSubplot:xlabel='Pool QC'>

# %%
plt.scatter(train['Pool QC'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Fence: Fence quality
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Fence'].isnull().sum()) +
                        '|Test:'+ str(test['Fence'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1651|Test:706|

# %%
#Recode missing value as None
train['Fence'] = train['Fence'].replace(np.nan, 'None')
test['Fence'] = test['Fence'].replace(np.nan, 'None')

# %%
train['Fence'].value_counts().sort_index(ascending=True)
# Out:
# GdPrv      83
# GdWo       80
# MnPrv     227
# MnWw       10
# None     1651
# Name: Fence, dtype: int64

# %%
test['Fence'].value_counts().sort_index(ascending=True)
# Out:
# GdPrv     35
# GdWo      32
# MnPrv    103
# MnWw       2
# None     706
# Name: Fence, dtype: int64

# %%
train.sort_values('Fence', inplace=True)
train['Fence'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Fence', inplace=True)
test['Fence'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Fence', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Fence', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Misc Feature: Miscellaneous feature not covered in other categories
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Misc Feature'].isnull().sum()) +
                        '|Test:'+ str(test['Misc Feature'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:1986|Test:837|

# %%
#Recode missing value as None
train['Misc Feature'] = train['Misc Feature'].replace(np.nan, 'None')
test['Misc Feature'] = test['Misc Feature'].replace(np.nan, 'None')

# %%
train['Misc Feature'].value_counts().sort_index(ascending=True)
# Out:
# Elev       1
# Gar2       4
# None    1986
# Othr       3
# Shed      56
# TenC       1
# Name: Misc Feature, dtype: int64

# %%
test['Misc Feature'].value_counts().sort_index(ascending=True)
# Out:
# Gar2      1
# None    837
# Othr      1
# Shed     39
# Name: Misc Feature, dtype: int64

# %%
train.sort_values('Misc Feature', inplace=True)
train['Misc Feature'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Misc Feature', inplace=True)
test['Misc Feature'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Misc Feature', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Misc Feature', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Misc Val: $Value of miscellaneous feature
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Misc Val'].isnull().sum()) +
                        '|Test:'+ str(test['Misc Val'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Misc Val'].describe()
# Out:
# count     2051.000000
# mean        51.574354
# std        573.393985
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      17000.000000
# Name: Misc Val, dtype: float64

# %%
test['Misc Val'].describe()
# Out:
# count      878.000000
# mean        48.498861
# std        550.169317
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      15500.000000
# Name: Misc Val, dtype: float64

# %%
train.sort_values('Misc Val', inplace=True)
train['Misc Val'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Misc Val', inplace=True)
test['Misc Val'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(train['Misc Val'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Mo Sold: Month Sold
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Mo Sold'].isnull().sum()) +
                        '|Test:'+ str(test['Mo Sold'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Mo Sold'].value_counts().sort_index(ascending=True)
# Out:
# 1      79
# 2     104
# 3     168
# 4     208
# 5     257
# 6     352
# 7     303
# 8     167
# 9     109
# 10    123
# 11    103
# 12     78
# Name: Mo Sold, dtype: int64

# %%
test['Mo Sold'].value_counts().sort_index(ascending=True)
# Out:
# 1      44
# 2      29
# 3      64
# 4      71
# 5     138
# 6     153
# 7     146
# 8      66
# 9      52
# 10     49
# 11     40
# 12     26
# Name: Mo Sold, dtype: int64

# %%
train.sort_values('Mo Sold', inplace=True)
train['Mo Sold'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Mo Sold', inplace=True)
test['Mo Sold'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Mo Sold', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Mo Sold', ylabel='SalePrice'>

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Numeric]</font>
#     Yr Sold: Year Sold
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Yr Sold'].isnull().sum()) +
                        '|Test:'+ str(test['Yr Sold'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
train['Yr Sold'].value_counts().sort_index(ascending=True)
# Out:
# 2006    438
# 2007    498
# 2008    435
# 2009    446
# 2010    234
# Name: Yr Sold, dtype: int64

# %%
test['Yr Sold'].value_counts().sort_index(ascending=True)
# Out:
# 2006    187
# 2007    195
# 2008    187
# 2009    202
# 2010    107
# Name: Yr Sold, dtype: int64

# %%
train.sort_values('Yr Sold', inplace=True)
train['Yr Sold'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Yr Sold', inplace=True)
test['Yr Sold'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train["Yr Sold"])
# Out:
# <AxesSubplot:xlabel='Yr Sold'>

# %%
sns.boxplot(x=test["Yr Sold"])
# Out:
# <AxesSubplot:xlabel='Yr Sold'>

# %%
plt.scatter(train['Yr Sold'], train['SalePrice'], alpha=0.5)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %% [markdown]
# <font size="3"><b>
#     <font color ='red'>[Categorical]</font>
#     Sale Type: Type of sale
#     </b></font>

# %%
print('Missing Data|' + 'Train:' + str(train['Sale Type'].isnull().sum()) +
                        '|Test:'+ str(test['Sale Type'].isnull().sum()) + '|')
# Out:
# Missing Data|Train:0|Test:0|

# %%
#Recode "WD " to "WD"
train['Sale Type'] = train['Sale Type'].replace("WD ", 'WD')
test['Sale Type'] = test['Sale Type'].replace("WD ", 'WD')

# %%
train['Sale Type'].value_counts().sort_index(ascending=True)
# Out:
# COD        63
# CWD        10
# Con         4
# ConLD      17
# ConLI       7
# ConLw       5
# New       160
# Oth         4
# WD       1781
# Name: Sale Type, dtype: int64

# %%
test['Sale Type'].value_counts().sort_index(ascending=True)
# Out:
# COD       24
# CWD        2
# Con        1
# ConLD      9
# ConLI      2
# ConLw      3
# New       78
# Oth        3
# VWD        1
# WD       755
# Name: Sale Type, dtype: int64

# %%
train.sort_values('Sale Type', inplace=True)
train['Sale Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
test.sort_values('Sale Type', inplace=True)
test['Sale Type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Sale Type', y='SalePrice', data=train)
# Out:
# <AxesSubplot:xlabel='Sale Type', ylabel='SalePrice'>

# %%
train = train.sort_values(by=['Id'])
test = test.sort_values(by=['Id'])

# %% [markdown]
# <font size="3"><b>Export Processed Data</b></font><br>
# <font color ='blue'>
# <br>
# </font>

# %%
train.to_csv(r'./datasets/train_clean.csv')
test.to_csv(r'./datasets/test_clean.csv')
